# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline
import os

# %%
a = np.array([[1, 2, 3],[4,5,6]])
b = np.array([[123,12,423],[10,11,21]])

c = np.concatenate((a,b), axis=0)
print c
print "\n"
d = np.concatenate((a,b), axis=1)
print d
# Out:
# [[  1   2   3]
#  [  4   5   6]
#  [123  12 423]
#  [ 10  11  21]]
#
#
# [[  1   2   3 123  12 423]
#  [  4   5   6  10  11  21]]

# %%
f1 = np.load('./dataset/my_face_data.npy')
l1 = np.load('./dataset/my_face_labels.npy')
# t1 = np.load('./dataset/test.npy')
f2 = np.load('./dataset/ashish_data.npy')
l2 = np.load('./dataset/ashish_labels.npy')

f3 = np.load('./dataset/sachin_data.npy')
l3 = np.load('./dataset/sachin_labels.npy')

print f1.shape, l1.shape, f2.shape, l2.shape, f3.shape, l3.shape
# Out:
# (6, 100, 100) (6,) (5, 100, 100) (5,) (8, 100, 100) (8,)

# %%
data  = np.array([])
data = np.concatenate((f1,f2), axis=0)
data = np.concatenate((data,f3), axis=0)
lab = np.concatenate((l1,l2), axis=0)
lab = np.concatenate((lab,l3),axis=0)
# print data[0].flatten().shape, lab.shape
for i in range(19):
    plt.figure(0)
    plt.imshow(data[i].reshape((100,100)), cmap='gray')
    plt.show()
    print lab[i]
# Out:
# laksh
# laksh
# laksh
# laksh
# laksh
# laksh
# ashish
# ashish
# ashish
# ashish
# ashish
# sachin
# sachin
# sachin
# sachin
# sachin
# sachin
# sachin
# sachin

# %%
np.save('./dataset/face_data', data)
np.save('./dataset/face_lab', lab)
